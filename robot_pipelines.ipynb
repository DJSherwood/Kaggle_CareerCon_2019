# %% [markdown]
# ## Import Libraries

# %%
import gc
import os
import logging
import datetime
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from subprocess import check_output
from sklearn.compose import ColumnTransformer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectPercentile, mutual_info_regression
from sklearn.impute import SimpleImputer 
from sklearn.impute import MissingIndicator
from sklearn.linear_model import RidgeClassifier
from sklearn.metrics import mean_squared_error, confusion_matrix
from sklearn.metrics import roc_auc_score, roc_curve, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import StratifiedKFold, GroupKFold, GroupShuffleSplit
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import FeatureUnion
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import reciprocal, uniform

#warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('X_train.csv')
test = pd.read_csv('X_test.csv')
y = pd.read_csv('y_train.csv')

# %%
train = train.set_index('series_id').join(y.set_index('series_id'))
trainb = train.loc[train['group_id'].isin([2,7,13,23,37,49])]

# %%
train.head()
# Out:
#           row_id  measurement_number  orientation_X  orientation_Y  \
# series_id
# 0            0_0                   0       -0.75853       -0.63435
# 0            0_1                   1       -0.75853       -0.63434
# 0            0_2                   2       -0.75853       -0.63435
# 0            0_3                   3       -0.75852       -0.63436
# 0            0_4                   4       -0.75852       -0.63435
#
#            orientation_Z  orientation_W  angular_velocity_X  \
# series_id
# 0               -0.10488       -0.10597            0.107650
# 0               -0.10490       -0.10600            0.067851
# 0               -0.10492       -0.10597            0.007275
# 0               -0.10495       -0.10597           -0.013053
# 0               -0.10495       -0.10596            0.005135
#
#            angular_velocity_Y  angular_velocity_Z  linear_acceleration_X  \
# series_id
# 0                    0.017561            0.000767               -0.74857
# 0                    0.029939            0.003385                0.33995
# 0                    0.028934           -0.005978               -0.26429
# 0                    0.019448           -0.008974                0.42684
# 0                    0.007652            0.005245               -0.50969
#
#            linear_acceleration_Y  linear_acceleration_Z  group_id  \
# series_id
# 0                         2.1030                -9.7532        13
# 0                         1.5064                -9.4128        13
# 0                         1.5922                -8.7267        13
# 0                         1.0993               -10.0960        13
# 0                         1.4689               -10.4410        13
#
#                  surface
# series_id
# 0          fine_concrete
# 0          fine_concrete
# 0          fine_concrete
# 0          fine_concrete
# 0          fine_concrete

# %%
train.groupby(['group_id']).agg('count')
# Out:
#           row_id  measurement_number  orientation_X  orientation_Y  \
# group_id
# 0           7296                7296           7296           7296
# 1           4864                4864           4864           4864
# 2           2304                2304           2304           2304
# 3           7296                7296           7296           7296
# 4           7296                7296           7296           7296
# 5           1152                1152           1152           1152
# 6           6144                6144           6144           6144
# 7           7168                7168           7168           7168
# 8           7296                7296           7296           7296
# 9           7296                7296           7296           7296
# 10          7168                7168           7168           7168
# 11          7168                7168           7168           7168
# 12          7296                7296           7296           7296
# 13          7296                7296           7296           7296
# 14          7168                7168           7168           7168
# 15          7296                7296           7296           7296
# 16          5760                5760           5760           5760
# 17          1536                1536           1536           1536
# 18          7296                7296           7296           7296
# 19          7296                7296           7296           7296
# 20          7296                7296           7296           7296
# 21          7296                7296           7296           7296
# 22          7296                7296           7296           7296
# 23          7168                7168           7168           7168
# 24           640                 640            640            640
# 25          6528                6528           6528           6528
# 26          7296                7296           7296           7296
# 27          2688                2688           2688           2688
# 28          4608                4608           4608           4608
# 29          7296                7296           7296           7296
# ...          ...                 ...            ...            ...
# 43          8960                8960           8960           8960
# 44          9088                9088           9088           9088
# 45          8960                8960           8960           8960
# 46          8960                8960           8960           8960
# 47          8960                8960           8960           8960
# 72                         8960                   8960     8960
#
# [73 rows x 13 columns]

# %%
## Step 1: feature engineering: A) convert to euler B) polynomial features
quats = ['orientation_X','orientation_Y','orientation_Z','orientation_W']
feat_engineering = ColumnTransformer(
    transformers = [
        ('add_features', PolynomialFeatures(degree=2,interaction_only=True,include_bias=False), quats )
    ]
)

## Step 2: standardize? I need to think carefully about my cross-validation scheme
try_pipe = Pipeline([
    ('add_features', PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)),
    ('standardize', StandardScaler())
])

# %%
## Step3: LabelEncode
encoded_response=pd.DataFrame()
instance_LabelEncoder = LabelEncoder()
encoded_response['surface'] = instance_LabelEncoder.fit_transform(train['surface'])

# %%
## Step4: split train into train and validation set
X_train, X_val, y_train, y_val = train_test_split(train[['orientation_X','orientation_Y','orientation_Z','orientation_W', \
                                                        'angular_velocity_X','angular_velocity_Y','angular_velocity_Z', \
                                                        'linear_acceleration_X','linear_acceleration_Y','linear_acceleration_Z']],
                                                  encoded_response['surface'], 
                                                  test_size = 0.2)

# %% [markdown]
# ## Random Forest (second try)

# %%
class_pipe = Pipeline([
    ('pipeline', try_pipe),
    ('classif', RandomForestClassifier())
])

parameters = [
                  {
                      'classif__max_depth': [8,10,12],
                      'classif__n_estimators': [5, 10, 15],
                      'classif__min_samples_leaf': [2,4]
                  }
             ]

# Define addtional variables in hopes of increasing readability
X_data = train[['orientation_X','orientation_Y','orientation_Z','orientation_W','angular_velocity_X','angular_velocity_Y','angular_velocity_Z','linear_acceleration_X','linear_acceleration_Y','linear_acceleration_Z']]
y_data = encoded_response['surface']
grp_data = train['group_id']
X = X_data.values
y = y_data.values

# Instantiate groupshufflesplit
gss = GroupShuffleSplit(n_splits = 9, test_size = 0.2, random_state=42)

model_list={}
# Loop through the training/testing indicies for cross validation
for i, (train_indices, val_indices) in enumerate(gss.split(X = X_data, y=y_data, groups=grp_data)):
    
    # Define training and test sets
    X_train, X_valid = X[train_indices], X[val_indices]
    y_train, y_valid = y[train_indices], y[val_indices]
       
    #print('Train Size: %s | Test: %s' % (train_indices.shape, val_indices.shape))
    
    # Define name for dictionary
    name=str('GroupFold') + str(i)
    
    # Perform cross-validation within a loop
    GrdSrch = GridSearchCV(class_pipe, parameters, verbose=2, cv = 3, scoring='accuracy')
    classif = GrdSrch.fit(X_train, y_train)
    score = classif.score(X_valid, y_valid)
    print("{} score: {}".format(name, score))
    
    model_list[name] = classif
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.4s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.9s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  26.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.4s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  23.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  23.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  23.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  27.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  27.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  27.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  27.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  24.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  22.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  21.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  31.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  31.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  31.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  21.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  21.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  21.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  31.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  31.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  30.8s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 19.1min finished
# GroupFold0 score: 0.35858784634760704
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.3s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  24.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  23.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  24.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  16.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  24.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  23.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  23.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  27.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  27.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  27.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  29.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  12.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  21.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  21.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  21.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  31.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  30.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  30.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  12.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  21.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  21.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  23.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  31.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  30.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  31.5s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 18.8min finished
# GroupFold1 score: 0.27231725374064836
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.9s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.4s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  18.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  18.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  20.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  20.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  29.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 17.5min finished
# GroupFold2 score: 0.2285
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.4s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  21.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  21.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.4s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  21.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 17.2min finished
# GroupFold3 score: 0.4268846099088838
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.8s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  23.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  16.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  16.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  18.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  18.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  18.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  26.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  26.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  26.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  26.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  26.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  26.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# ...
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.7s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  26.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  20.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.5s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 17.3min finished
# GroupFold7 score: 0.36794777684563756
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.5s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  16.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, total=  15.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, total=  22.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, total=   9.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, total=  15.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.1s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, total=  22.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, total=  25.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, total=  10.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  18.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, total=  17.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, total=  25.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  20.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, total=  19.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, total=  28.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, total=  19.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, total=  28.3s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 17.3min finished
# GroupFold8 score: 0.16123744419642858

# %%
model_list['GroupFold8'].get_params()
# Out:
# {'cv': 3,
#  'error_score': 'raise-deprecating',
#  'estimator__memory': None,
#  'estimator__steps': [('pipeline', Pipeline(memory=None,
#         steps=[('add_features', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)), ('standardize', StandardScaler(copy=True, with_mean=True, with_std=True))])),
#   ('classif',
#    RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                max_depth=None, max_features='auto', max_leaf_nodes=None,
#                min_impurity_decrease=0.0, min_impurity_split=None,
#                min_samples_leaf=1, min_samples_split=2,
#                min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#                oob_score=False, random_state=None, verbose=0,
#                warm_start=False))],
#  'estimator__pipeline': Pipeline(memory=None,
#       steps=[('add_features', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)), ('standardize', StandardScaler(copy=True, with_mean=True, with_std=True))]),
#  'estimator__classif': RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#              max_depth=None, max_features='auto', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False),
#  'estimator__pipeline__memory': None,
#  'estimator__pipeline__steps': [('add_features',
#    PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)),
#   ('standardize', StandardScaler(copy=True, with_mean=True, with_std=True))],
#  'estimator__pipeline__add_features': PolynomialFeatures(degree=2, include_bias=False, interaction_only=True),
#  'estimator__pipeline__standardize': StandardScaler(copy=True, with_mean=True, with_std=True),
#  'estimator__pipeline__add_features__degree': 2,
#  'estimator__pipeline__add_features__include_bias': False,
#  'estimator__pipeline__add_features__interaction_only': True,
#  'estimator__pipeline__standardize__copy': True,
#  'estimator__pipeline__standardize__with_mean': True,
#  'estimator__pipeline__standardize__with_std': True,
#  'estimator__classif__bootstrap': True,
#  'estimator__classif__class_weight': None,
#  'estimator__classif__criterion': 'gini',
#  'estimator__classif__max_depth': None,
#  'estimator__classif__max_features': 'auto',
#  'estimator__classif__max_leaf_nodes': None,
#  'estimator__classif__min_impurity_decrease': 0.0,
#  'estimator__classif__min_impurity_split': None,
#  'estimator__classif__min_samples_leaf': 1,
#  'estimator__classif__min_samples_split': 2,
#  'estimator__classif__min_weight_fraction_leaf': 0.0,
#  'estimator__classif__n_estimators': 'warn',
#  'estimator__classif__n_jobs': None,
#  'estimator__classif__oob_score': False,
#  'estimator__classif__random_state': None,
#  'estimator__classif__verbose': 0,
#  'estimator__classif__warm_start': False,
#  'estimator': Pipeline(memory=None,
#       steps=[('pipeline', Pipeline(memory=None,
#       steps=[('add_features', PolynomialFeatures(degree=2, include_bias=False, interaction_only=True)), ('standardize', StandardScaler(copy=True, with_mean=True, with_std=True))])), ('classif', RandomForestClassifier(bootstrap=True, class_weight=None, criteri...obs=None,
#              oob_score=False, random_state=None, verbose=0,
#              warm_start=False))]),
#  'fit_params': None,
#  'iid': 'warn',
#  'n_jobs': None,
#  'param_grid': [{'classif__max_depth': [8, 10, 12],
#    'classif__n_estimators': [5, 10, 15],
#    'classif__min_samples_leaf': [2, 4]}],
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': 'warn',
#  'scoring': 'accuracy',
#  'verbose': 2}

# %% [markdown]
# ## Random Forest (first try)

# %%
## Step5: Train Classifier(s) 
names = [
         "Random Forest Classifier"
        ]

classifier = [
    RandomForestClassifier()
]

parameters = [
                  {
                      'classif__max_depth': [8,10,12],
                      'classif__n_estimators': [5, 10, 15],
                      'classif__min_samples_leaf': [2,4],
                      'classif__n_jobs': [4]
                  }
             ]

model_list = {}
for name, classifier, params in zip(names, classifier, parameters):
    class_pipe = Pipeline([
        ('pipeline', try_pipe),
        ('classif', classifier),
    ])
    gs_classif = GridSearchCV(class_pipe, params, verbose=2, cv = 5, scoring='accuracy')
    classif = gs_classif.fit(X_train, y_train)
    score = classif.score(X_val, y_val)
    print("{} score: {}".format(name, score))
    model_list[name] = classif

## To include later?
# for train_index, test_index in group_kfold.split(X, y, groups):
#    folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=59)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  11.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.5s remaining:    0.0s
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.0s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  12.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  12.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  12.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  12.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  12.8s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  16.3s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  16.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  16.4s
# [CV] classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  16.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  12.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  12.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  12.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  12.7s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  12.9s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  16.5s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  16.6s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=8, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  16.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  10.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  10.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=   9.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  14.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  14.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  14.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  14.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  14.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  18.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  18.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  17.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  18.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=   9.8s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  10.0s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  10.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.3s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  17.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  15.5s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  15.1s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  19.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  19.6s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  19.9s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  19.4s
# [CV] classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=10, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  18.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  10.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  11.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  10.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=5, classif__n_jobs=4, total=  11.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  15.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  15.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  15.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=10, classif__n_jobs=4, total=  16.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  20.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  21.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  20.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  22.9s
# [CV] classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=2, classif__n_estimators=15, classif__n_jobs=4, total=  21.1s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.3s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.2s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=5, classif__n_jobs=4, total=  11.4s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  15.7s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  16.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  17.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  17.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=10, classif__n_jobs=4, total=  15.8s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  22.5s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  20.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  22.0s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  22.6s
# [CV] classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4
# [CV]  classif__max_depth=12, classif__min_samples_leaf=4, classif__n_estimators=15, classif__n_jobs=4, total=  22.4s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed: 24.6min finished
# Random Forest Classifier score: 0.9905778379265092

# %%
model_list['Random Forest Classifier'].best_params_
# Out:
# {'classif__max_depth': 12,
#  'classif__min_samples_leaf': 2,
#  'classif__n_estimators': 15,
#  'classif__n_jobs': 4}

# %% [markdown]
# ## Fit Final

# %% [markdown]
# ## Predict & Submit

# %%
## Generate Predictions
y_hat = gs_classif.best_estimator_.predict(test[['orientation_X','orientation_Y','orientation_Z','orientation_W', \
                                                        'angular_velocity_X','angular_velocity_Y','angular_velocity_Z', \
                                                        'linear_acceleration_X','linear_acceleration_Y','linear_acceleration_Z']])

## Transform back to labels
test['surface'] = instance_LabelEncoder.inverse_transform(y_hat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ce6bb96f956b> in <module>
#       2 y_hat = gs_classif.best_estimator_.predict(test[['orientation_X','orientation_Y','orientation_Z','orientation_W', \
#       3                                                         'angular_velocity_X','angular_velocity_Y','angular_velocity_Z', \
# ----> 4                                                         'linear_acceleration_X','linear_acceleration_Y','linear_acceleration_Z']])
#       5
#       6 ## Transform back to labels
#
# ~/anaconda3/envs/kaggle_comps/lib/python3.6/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     116
#     117         # lambda, but not partial, allows help() to work with update_wrapper
# --> 118         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     119         # update the docstring of the returned function
#     120         update_wrapper(out, self.fn)
#
# ~/anaconda3/envs/kaggle_comps/lib/python3.6/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     329         for name, transform in self.steps[:-1]:
#     330             if transform is not None:
# --> 331                 Xt = transform.transform(Xt)
#     332         return self.steps[-1][-1].predict(Xt, **predict_params)
#     333
#
# ~/anaconda3/envs/kaggle_comps/lib/python3.6/site-packages/sklearn/pipeline.py in _transform(self, X)
#     449         for name, transform in self.steps:
#     450             if transform is not None:
# --> 451                 Xt = transform.transform(Xt)
#     452         return Xt
#     453
#
# ~/anaconda3/envs/kaggle_comps/lib/python3.6/site-packages/sklearn/preprocessing/data.py in transform(self, X)
#    1487
#    1488         if n_features != self.n_input_features_:
# -> 1489             raise ValueError("X shape does not match training shape")
#    1490
#    1491         combinations = self._combinations(n_features, self.degree,
#
# ValueError: X shape does not match training shape

# %%
## join to submission file
submission = pd.read_csv(os.path.join(PATH,'sample_submission.csv'))
answers = test.groupby('series_id').first()[['surface']]
submission['surface'] = answers['surface']

## save as csv
submission.to_csv('submission_29Mar2019b_djs.csv', index=False)
